# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavjiyer87/engine-nvh-deep-learning/blob/main/00_colab_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Colab Setup Notebook

from google.colab import drive
drive.mount("/content/drive")

PROJECT_DRIVE = (
    "/content/drive/MyDrive/"
    "NVH_DeepLearning/01_EngineOperatingState"
)

RAW_DATA_DIR = f"{PROJECT_DRIVE}/data/raw"
MANIFEST_DIR = f"{PROJECT_DRIVE}/data/manifests"
PROCESSED_DATA_DIR = f"{PROJECT_DRIVE}/data/processed"
FEATURE_DIR = f"{PROJECT_DRIVE}/data/cached_features"
MODEL_DIR = f"{PROJECT_DRIVE}/models"
OUTPUT_DIR = f"{PROJECT_DRIVE}/outputs"
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path

project_directories = [
    RAW_DATA_DIR,
    MANIFEST_DIR,
    PROCESSED_DATA_DIR,
    FEATURE_DIR,
    MODEL_DIR,
    OUTPUT_DIR,
]

for directory in project_directories:
    Path(directory).mkdir(parents=True, exist_ok=True)
    print(f"Ready: {directory}")
# Out:
# Ready: /content/drive/MyDrive/NVH_DeepLearning/01_EngineOperatingState/data/raw
# Ready: /content/drive/MyDrive/NVH_DeepLearning/01_EngineOperatingState/data/manifests
# Ready: /content/drive/MyDrive/NVH_DeepLearning/01_EngineOperatingState/data/processed
# Ready: /content/drive/MyDrive/NVH_DeepLearning/01_EngineOperatingState/data/cached_features
# Ready: /content/drive/MyDrive/NVH_DeepLearning/01_EngineOperatingState/models
# Ready: /content/drive/MyDrive/NVH_DeepLearning/01_EngineOperatingState/outputs

# %%
# Clone the repository only if it has not already been cloned
# !git clone https://github.com/vaibhavjiyer87/engine-nvh-deep-learning.git

# Change into the repository directory
# %cd /content/engine-nvh-deep-learning

# Confirm the file exists
# !ls -la
# Out:
# Cloning into 'engine-nvh-deep-learning'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 74 (delta 25), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 340.92 KiB | 6.56 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# /content/engine-nvh-deep-learning
# total 52
# drwxr-xr-x 10 root root 4096 Aug  3 12:33 .
# drwxr-xr-x  1 root root 4096 Aug  3 12:31 ..
# drwxr-xr-x  2 root root 4096 Aug  3 12:31 configs
# drwxr-xr-x  2 root root 4096 Aug  3 12:31 data
# drwxr-xr-x  9 root root 4096 Aug  3 12:33 engine-nvh-deep-learning
# drwxr-xr-x  8 root root 4096 Aug  3 12:31 .git
# -rw-r--r--  1 root root    1 Aug  3 12:31 .gitignore
# drwxr-xr-x  2 root root 4096 Aug  3 12:31 notebooks
# -rw-r--r--  1 root root  699 Aug  3 12:31 README.md
# drwxr-xr-x  2 root root 4096 Aug  3 12:31 reports
# -rw-r--r--  1 root root   84 Aug  3 12:31 requirements.txt
# ...

# %%
# %cd /content/engine-nvh-deep-learning
# !git pull
# !ls -la
# !pip install -q -r requirements.txt
# Out:
# /content/engine-nvh-deep-learning
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 947 bytes | 947.00 KiB/s, done.
# From https://github.com/vaibhavjiyer87/engine-nvh-deep-learning
#    287e345..9849120  main       -> origin/main
# Updating 287e345..9849120
# Fast-forward
#  requirements.txt | 1 -
#  1 file changed, 1 deletion(-)
# total 52
# drwxr-xr-x 10 root root 4096 Aug  3 12:35 .
# drwxr-xr-x  1 root root 4096 Aug  3 12:31 ..
# drwxr-xr-x  2 root root 4096 Aug  3 12:31 configs
# drwxr-xr-x  2 root root 4096 Aug  3 12:31 data
# drwxr-xr-x  9 root root 4096 Aug  3 12:33 engine-nvh-deep-learning
# drwxr-xr-x  8 root root 4096 Aug  3 12:35 .git
# -rw-r--r--  1 root root    1 Aug  3 12:31 .gitignore
# drwxr-xr-x  2 root root 4096 Aug  3 12:31 notebooks
# ...
